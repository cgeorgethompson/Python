# %%
from carModule import CarRental, Customer

def main():
    shop = CarRental(100)
    customer = Customer()

    while True:
        print("""
        ====== Car Rental Shop =======
        1. Display available cars
        2. Request a car on hourly basis $5
        3. Request a car on daily basis $20
        4. Request a car on weekly basis $60
        5. Return a car
        6. Exit
        """)
        
        choice = input("Enter choice: ")
        
        try:
            choice = int(choice)
        except ValueError:
            print("That's not an integer value!")
            continue
        
        if choice == 1:
            shop.displaystock()
        
        elif choice == 2:
            customer.rentalTime = shop.rentCarOnHourlyBasis(customer.requestCar())
            customer.rentalBasis = 1

        elif choice == 3:
            customer.rentalTime = shop.rentCarOnDailyBasis(customer.requestCar())
            customer.rentalBasis = 2

        elif choice == 4:
            customer.rentalTime = shop.rentCarOnWeeklyBasis(customer.requestCar())
            customer.rentalBasis = 3

        elif choice == 5:
            customer.bill = shop.returnCar(customer.returnCar())
            customer.rentalBasis, customer.rentalTime, customer.cars = 5,20,60        
        elif choice == 6:
            break
        else:
            print("Invalid input. Please enter number between 1-6 ")        
    print("Thank you for using the car rental system.")


if __name__=="__main__":
    main()
# Out:
#         ====== Car Rental Shop =======
#         1. Display available cars
#         2. Request a car on hourly basis $5
#         3. Request a car on daily basis $20
#         4. Request a car on weekly basis $60
#         5. Return a car
#         6. Exit
#
# Enter choice: 1
# We have currently 100 cars available to rent.
#
#         ====== Car Rental Shop =======
#         1. Display available cars
#         2. Request a car on hourly basis $5
#         3. Request a car on daily basis $20
#         4. Request a car on weekly basis $60
#         5. Return a car
#         6. Exit
#
# Enter choice: 3
# How many cars would you like to rent?5
# You have rented 5 car(s) on daily basis today at 12 hours.
# You will be charged $20 for each day per car.
# We hope that you enjoy our service.
#
#         ====== Car Rental Shop =======
#         1. Display available cars
#         2. Request a car on hourly basis $5
#         3. Request a car on daily basis $20
#         4. Request a car on weekly basis $60
#         5. Return a car
#         6. Exit
#
# Enter choice: 1
# We have currently 95 cars available to rent.
#
#         ====== Car Rental Shop =======
#         1. Display available cars
#         2. Request a car on hourly basis $5
#         3. Request a car on daily basis $20
#         4. Request a car on weekly basis $60
#         5. Return a car
#         6. Exit
#
# Enter choice: 5
# You are eligible for Family rental promotion of 30% discount
# Thanks for returning your car. Hope you enjoyed our service!
# That would be $0.0
#
#         ====== Car Rental Shop =======
#         1. Display available cars
#         2. Request a car on hourly basis $5
#         3. Request a car on daily basis $20
#         4. Request a car on weekly basis $60
#         5. Return a car
#         6. Exit
